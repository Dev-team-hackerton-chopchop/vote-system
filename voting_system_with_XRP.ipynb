# %%
import xrpl
from xrpl.clients import JsonRpcClient
from xrpl.models.transactions import Payment, Memo
from xrpl.models.requests import AccountTx, AccountInfo
from xrpl.wallet import generate_faucet_wallet
from xrpl.transaction import autofill_and_sign, submit_and_wait
import nest_asyncio
import time

# asyncio 관련 에러 해결을 위한 nest_asyncio 적용
nest_asyncio.apply()

# XRP Ledger 클라이언트 설정
JSON_RPC_URL = "https://s.altnet.rippletest.net:51234/"  # 테스트넷 URL
client = JsonRpcClient(JSON_RPC_URL)

def create_wallet():
    # Wallet 생성
    wallet = generate_faucet_wallet(client, debug=True)
    return wallet

def check_balance(wallet):
    # 잔액 확인
    account_info = client.request(AccountInfo(account=wallet.classic_address))
    balance = account_info.result['account_data']['Balance']
    print(f"Account balance: {balance}")
    return balance

def create_vote(wallet, vote_id, vote_topic, options):
    # 더미 주소 사용
    dummy_address = "rPT1Sjq2YGrBMTttX4GZHjKu9dyfzbpAYe"
    
    # 투표를 생성하는 함수
    memo_data = f"VOTE:{vote_id}:{vote_topic}:{','.join(options)}"
    create_vote_tx = Payment(
        account=wallet.classic_address,
        amount="1",
        destination=dummy_address,
        memos=[Memo(
            memo_data=memo_data.encode("utf-8").hex(),
            memo_format="text/plain".encode("utf-8").hex(),
            memo_type="vote/create".encode("utf-8").hex()
        )]
    )
    
    # 트랜잭션 자동 완성 및 서명
    signed_tx = autofill_and_sign(create_vote_tx, client, wallet)
    
    # 트랜잭션 제출 및 결과 확인
    response = submit_and_wait(signed_tx, client)
    
    if response.is_successful():
        print("Vote creation transaction was successfully submitted!")
        print("Transaction hash:", response.result['hash'])
        return response.result['hash']
    else:
        print("Vote creation failed:", response.result)
        raise ValueError("Transaction failed or unexpected response structure")

def cast_vote(wallet, vote_id, option, vote_choice):
    # 더미 주소 사용
    dummy_address = "rPT1Sjq2YGrBMTttX4GZHjKu9dyfzbpAYe"
    
    # Memo 데이터에 투표 ID, 옵션, 그리고 선택한 투표 결과 (O/X) 포함
    memo_data = f"VOTE:{vote_id}:{option}:{vote_choice}"
    
    vote_tx = Payment(
        account=wallet.classic_address,
        amount="1",
        destination=dummy_address,
        memos=[Memo(
            memo_data=memo_data.encode("utf-8").hex(),
            memo_format="text/plain".encode("utf-8").hex(),
            memo_type="vote/cast".encode("utf-8").hex()
        )]
    )
    signed_tx = autofill_and_sign(vote_tx, client, wallet)
    response = submit_and_wait(signed_tx, client)
    
    if response.is_successful():
        print("Vote cast transaction was successfully submitted!")
        print("Transaction hash:", response.result['hash'])
        return response.result['hash']
    else:
        print("Vote casting failed:", response.result)
        raise ValueError("Transaction failed or unexpected response structure")
    
def tally_votes(wallet, vote_id):
    # 트랜잭션 조회시 binary=False 설정
    account_tx_request = AccountTx(account=wallet.classic_address, binary=False)
    response = client.request(account_tx_request)

    print("Account Transactions Response:", response.result)
    
    memo_summaries = []
    # 트랜잭션을 순회하며 Memo 데이터를 찾음
    for i, tx in enumerate(response.result['transactions']):
        # tx_json 필드에서 실제 트랜잭션 데이터를 가져옴
        tx_data = tx.get('tx_json', {})
        
        print(f"Transaction {i+1} - Hash: {tx_data.get('hash')}")
        
        if 'Memos' in tx_data:
            print(f"Memos found in Transaction {i+1}")
            for memo in tx_data['Memos']:
                memo_data_hex = memo['Memo'].get('MemoData', None)
                
                if memo_data_hex:
                    # 헥사코드를 UTF-8 문자열로 디코딩
                    memo_data = bytes.fromhex(memo_data_hex).decode('utf-8')
                    print(f"Decoded MemoData from Transaction {i+1}: {memo_data}")
                    
                    # MemoData를 분석하여 요약 정보 추출
                    parts = memo_data.split(':')
                    if len(parts) >= 4:
                        vote_id = parts[1]
                        option = parts[2]
                        vote_choice = parts[3]
                        summary = {
                            'Transaction': i + 1,
                            'Vote ID': vote_id,
                            'Option': option,
                            'Vote': vote_choice
                        }
                        memo_summaries.append(summary)
                    else:
                        print(f"Unexpected Memo format in Transaction {i+1}: {memo_data}")
                else:
                    print(f"MemoData not found in Memos of Transaction {i+1}")
        else:
            print(f"No Memos found in Transaction {i+1}")
    
    if not memo_summaries:
        print("No memo summaries were collected across all transactions.")
    else:
        print("\nMemo Summaries from all transactions:")
        for summary in memo_summaries:
            print(f"Transaction {summary['Transaction']}: Vote ID {summary['Vote ID']}, Option: {summary['Option']}, Vote: {summary['Vote']}")
    
    return memo_summaries

def main():
    wallet = create_wallet()
    
    # 잔액 확인
    check_balance(wallet)

    vote_id = "001"
    vote_topic = "Favorite Programming Language"
    options = ["Python", "JavaScript", "Rust", "Go"]
    first_vote_hash = create_vote(wallet, vote_id, vote_topic, options)

    # 각 트랜잭션마다 대기 시간을 추가
    time.sleep(5)
    cast_vote(wallet, vote_id, "Python", "O")
    time.sleep(5)
    cast_vote(wallet, vote_id, "JavaScript", "X")
    time.sleep(5)
    cast_vote(wallet, vote_id, "Rust", "O")
    time.sleep(5)
    cast_vote(wallet, vote_id, "Go", "X")

    results = tally_votes(wallet, vote_id)
    print("Final Memo Summaries:", results)

main()
# Out:
# Attempting to fund address rMiM33sLW26Ap1yQGa9cKsesv5epLuZoig
# Faucet fund successful.
# Account balance: 100000000
# Vote creation transaction was successfully submitted!
# Transaction hash: B5A2B5794DB96AD855458F044C350A7D4194EEC999F9F297EA2FEDE84D0BF059
# Vote cast transaction was successfully submitted!
# Transaction hash: A60272221BE6367C47C4E261575FE715D14E4C250B4607714C0A8104A9E3B93A
# Vote cast transaction was successfully submitted!
# Transaction hash: 57E229ED117165D3A4C61F9672A70832F906F47DC398154F2693A0D3C844E2CB
# Vote cast transaction was successfully submitted!
# Transaction hash: 9C448046DE761260C22488CC70C9A29BAA8325CD758F85A4E6590B3A28896C4F
# Vote cast transaction was successfully submitted!
# Transaction hash: 01B2A670813950531427E30D6AE12627622B8A80E4A5D79C53419879C6CD731E
# Account Transactions Response: {'account': 'rMiM33sLW26Ap1yQGa9cKsesv5epLuZoig', 'ledger_index_max': 118261, 'ledger_index_min': 7, 'limit': 0, 'transactions': [{'close_time_iso': '2024-08-23T12:12:12Z', 'hash': '01B2A670813950531427E30D6AE12627622B8A80E4A5D79C53419879C6CD731E', 'ledger_hash': 'C62456D8E300053B9BA41E7F4F8D309821C683E098CF32BA11A99392760C767D', 'ledger_index': 118261, 'meta': {'AffectedNodes': [{'ModifiedNode': {'FinalFields': {'Account': 'rPT1Sjq2YGrBMTttX4GZHjKu9dyfzbpAYe', 'Balance': '1885643507095368', 'Flags': 0, 'OwnerCount': 179, 'Sequence': 129303, 'TicketCount': 179}, 'LedgerEntryType': 'AccountRoot', 'LedgerIndex': '31CCE9D28412FF973E9AB6D0FA219BACF19687D9A2456A0C2ABC3280E9D47E37', 'PreviousFields': {'Balance': '1885643507095367'}, 'PreviousTxnID': '96DCBBF69BD86730FE6BC3E9AA9C96CE522523084A0255BFEEA155C8533AEBD6', 'PreviousTxnLgrSeq': 118258}}, {'ModifiedNode': {'FinalFields': {'Account': 'rMiM33sLW26Ap1yQGa9cKsesv5epLuZoig', 'Balance': '99999945', 'Flags': 0, 'OwnerCount': 0, 'Sequence': 118244}, 'LedgerEntryType': 'AccountRoot', 'LedgerIndex': '57D9AD530EC310E7D2BA2DDD76F5AF195C4E8F0201C0910FAF50544FCDF4C47E', 'PreviousFields': {'Balance': '99999956', 'Sequence': 118243}, 'PreviousTxnID': '9C448046DE761260C22488CC70C9A29BAA8325CD758F85A4E6590B3A28896C4F', 'PreviousTxnLgrSeq': 118256}}], 'TransactionIndex': 0, 'TransactionResult': 'tesSUCCESS', 'delivered_amount': '1'}, 'tx_json': {'Account': 'rMiM33sLW26Ap1yQGa9cKsesv5epLuZoig', 'DeliverMax': '1', 'Destination': 'rPT1Sjq2YGrBMTttX4GZHjKu9dyfzbpAYe', 'Fee': '10', 'Flags': 0, 'LastLedgerSequence': 118278, 'Memos': [{'Memo': {'MemoData': '564F54453A3030313A476F3A58', 'MemoFormat': '746578742F706C61696E', 'MemoType': '766F74652F63617374'}}], 'Sequence': 118243, 'SigningPubKey': 'ED9A747CDC8F0CD64463486676B97867976F1CB4592A4EB0B120A3E85E4C0873ED', 'TransactionType': 'Payment', 'TxnSignature': '2D12C245F2C2AD37522289252FE7C63E86BF646C7EA26B28173C0321A2314BE8FFF521DD1C2532D0785E41764B3950AFEE278BE6EBAAFA0E7B16296237281A03', 'date': 777730332, 'ledger_index': 118261}, 'validated': True}, {'close_time_iso': '2024-08-23T12:12:00Z', 'hash': '9C448046DE761260C22488CC70C9A29BAA8325CD758F85A4E6590B3A28896C4F', 'ledger_hash': 'B442417BB1AE86B9B5D9F64B862CA35BD36F2EA434ABDE0E4C8924221D4388A1', 'ledger_index': 118256, 'meta': {'AffectedNodes': [{'ModifiedNode': {'FinalFields': {'Account': 'rPT1Sjq2YGrBMTttX4GZHjKu9dyfzbpAYe', 'Balance': '1885643607095379', 'Flags': 0, 'OwnerCount': 180, 'Sequence': 129303, 'TicketCount': 180}, 'LedgerEntryType': 'AccountRoot', 'LedgerIndex': '31CCE9D28412FF973E9AB6D0FA219BACF19687D9A2456A0C2ABC3280E9D47E37', 'PreviousFields': {'Balance': '1885643607095378'}, 'PreviousTxnID': '57E229ED117165D3A4C61F9672A70832F906F47DC398154F2693A0D3C844E2CB', 'PreviousTxnLgrSeq': 118252}}, {'ModifiedNode': {'FinalFields': {'Account': 'rMiM33sLW26Ap1yQGa9cKsesv5epLuZoig', 'Balance': '99999956', 'Flags': 0, 'OwnerCount': 0, 'Sequence': 118243}, 'LedgerEntryType': 'AccountRoot', 'LedgerIndex': '57D9AD530EC310E7D2BA2DDD76F5AF195C4E8F0201C0910FAF50544FCDF4C47E', 'PreviousFields': {'Balance': '99999967', 'Sequence': 118242}, 'PreviousTxnID': '57E229ED117165D3A4C61F9672A70832F906F47DC398154F2693A0D3C844E2CB', 'PreviousTxnLgrSeq': 118252}}], 'TransactionIndex': 3, 'TransactionResult': 'tesSUCCESS', 'delivered_amount': '1'}, 'tx_json': {'Account': 'rMiM33sLW26Ap1yQGa9cKsesv5epLuZoig', 'DeliverMax': '1', 'Destination': 'rPT1Sjq2YGrBMTttX4GZHjKu9dyfzbpAYe', 'Fee': '10', 'Flags': 0, 'LastLedgerSequence': 118274, 'Memos': [{'Memo': {'MemoData': '564F54453A3030313A527573743A4F', 'MemoFormat': '746578742F706C61696E', 'MemoType': '766F74652F63617374'}}], 'Sequence': 118242, 'SigningPubKey': 'ED9A747CDC8F0CD64463486676B97867976F1CB4592A4EB0B120A3E85E4C0873ED', 'TransactionType': 'Payment', 'TxnSignature': '85C4A2E9160523223272309655D4D0AE1CD628EB0284499A4EFCDF0D2BCBAA983D1A1DBA74BF31AB07152BED5E7DE9CC79964A88FE47CB68E8DC8E3DB553D706', 'date': 777730320, 'ledger_inde ...
# Transaction 1 - Hash: None
# Memos found in Transaction 1
# Decoded MemoData from Transaction 1: VOTE:001:Go:X
# Transaction 2 - Hash: None
# Memos found in Transaction 2
# Decoded MemoData from Transaction 2: VOTE:001:Rust:O
# Transaction 3 - Hash: None
# Memos found in Transaction 3
# Decoded MemoData from Transaction 3: VOTE:001:JavaScript:X
# Transaction 4 - Hash: None
# Memos found in Transaction 4
# Decoded MemoData from Transaction 4: VOTE:001:Python:O
# Transaction 5 - Hash: None
# Memos found in Transaction 5
# Decoded MemoData from Transaction 5: VOTE:001:Favorite Programming Language:Python,JavaScript,Rust,Go
# Transaction 6 - Hash: None
# No Memos found in Transaction 6
#
# Memo Summaries from all transactions:
# Transaction 1: Vote ID 001, Option: Go, Vote: X
# Transaction 2: Vote ID 001, Option: Rust, Vote: O
# Transaction 3: Vote ID 001, Option: JavaScript, Vote: X
# Transaction 4: Vote ID 001, Option: Python, Vote: O
# Transaction 5: Vote ID 001, Option: Favorite Programming Language, Vote: Python,JavaScript,Rust,Go
# Final Memo Summaries: [{'Transaction': 1, 'Vote ID': '001', 'Option': 'Go', 'Vote': 'X'}, {'Transaction': 2, 'Vote ID': '001', 'Option': 'Rust', 'Vote': 'O'}, {'Transaction': 3, 'Vote ID': '001', 'Option': 'JavaScript', 'Vote': 'X'}, {'Transaction': 4, 'Vote ID': '001', 'Option': 'Python', 'Vote': 'O'}, {'Transaction': 5, 'Vote ID': '001', 'Option': 'Favorite Programming Language', 'Vote': 'Python,JavaScript,Rust,Go'}]
